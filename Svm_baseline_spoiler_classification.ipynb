# %%
# TfidfVectorizer + LinearSVC

# %%
import pandas as pd

from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd

ds_reviews = pd.read_json('/content/drive/MyDrive/IMDB_reviews.json', lines=True)

# %%
ds_reviews
# Out:
#              review_date   movie_id    user_id  is_spoiler  \
# 0       10 February 2006  tt0111161  ur1898687        True
# 1       6 September 2000  tt0111161  ur0842118        True
# 2          3 August 2001  tt0111161  ur1285640        True
# 3       1 September 2002  tt0111161  ur1003471        True
# 4            20 May 2004  tt0111161  ur0226855        True
# ...                  ...        ...        ...         ...
# 573908     8 August 1999  tt0139239  ur0100166       False
# 573909      31 July 1999  tt0139239  ur0021767       False
# 573910      20 July 1999  tt0139239  ur0392750       False
# 573911      11 June 1999  tt0139239  ur0349105       False
# 573912        3 May 1999  tt0139239  ur0156431       False
#
#                                               review_text  rating  \
# 0       In its Oscar year, Shawshank Redemption (writt...      10
# 1       The Shawshank Redemption is without a doubt on...      10
# 2       I believe that this film is the best story eve...       8
# 3       **Yes, there are SPOILERS here**This film has ...      10
# 4       At the heart of this extraordinary movie is a ...       8
# ...                                                   ...     ...
# 573908  Go is wise, fast and pure entertainment. Assem...      10
# 573909  Well, what shall I say. this one´s fun at any ...       9
# 573910  Go is the best movie I have ever seen, and I'v...      10
# 573911  Call this 1999 teenage version of Pulp Fiction...       3
# 573912  Why was this movie made? No doubt to sucker in...       2
#
#                                        review_summary
# 0       A classic piece of unforgettable film-making.
# 1          Simply amazing. The best film of the 90's.
# 2                    The best story ever told on film
# 3                          Busy dying or busy living?
# 4              Great story, wondrously told and acted
# ...                                               ...
# 573908            The best teen movie of the nineties
# 573909                             Go - see the movie
# 573910             It's the best movie I've ever seen
# 573911                   Haven't we seen this before?
# 573912                         Go doesn't go anywhere
#
# [573913 rows x 7 columns]

# %%
# train dataset (22000 examples -- approxamately the same size as with neural network)
# balanced classes: 11000 spoiler reviews and 11000 no spoiler reviews

spoiler_reviews = ds_reviews.loc[ds_reviews['is_spoiler'] == True]

small_spoiler_train = spoiler_reviews.sample(n=11000)

no_spoiler_reviews = ds_reviews.loc[ds_reviews['is_spoiler'] == False]

small_no_spoiler_train = no_spoiler_reviews.sample(n=11000)

train_reviews = pd.concat([small_spoiler_train, small_no_spoiler_train], ignore_index = False)
train_reviews
# Out:
#               review_date   movie_id     user_id  is_spoiler  \
# 257599   27 February 2017  tt4975722  ur36043108        True
# 42236        10 June 2006  tt0081505   ur8086637        True
# 147724        25 May 2011  tt1298650  ur26316341        True
# 155169    5 November 2011  tt0448694   ur3494091        True
# 423708  14 September 2015  tt0758758  ur60028700        True
# ...                   ...        ...         ...         ...
# 30539         4 June 1999  tt0120586   ur0337549       False
# 464007    13 January 2010  tt0988045  ur12431180       False
# 301377  17 September 2010  tt0163025  ur23794235       False
# 242454  23 September 2015  tt2719848  ur48675674       False
# 546444     26 August 2007  tt0120812   ur4872686       False
#
#                                               review_text  rating  \
# 257599  This is quite a surprising movie on many level...       8
# 42236   *******SPOILER ALERT******** Just got finished...       9
# 147724  First things, first : the fourth installment o...       5
# 155169  A fine, fun adventure for kids and their paren...      10
# 423708  Into the Wild (2007): Dir: Sean Penn / Cast: E...       8
# ...                                                   ...     ...
# 30539   After seeing this, I could understand why the ...       4
# 464007  Guy Ritchie brings a fresh look to the legenda...       9
# 301377  After the success of the first two Jp movies t...      10
# 242454  "Everest" (2015 release; 122 min.) brings the ...       9
# 546444  This isn't an Oscar winner, but it comes prett...       8
#
#                                            review_summary
# 257599                             Under the moon of love
# 42236   Possibly one of the most terrifying rising act...
# 147724               a disappointing end to a grande saga
# 155169                                  Beautiful and fun
# 423708                                  Hirsch Goes Wild.
# ...                                                   ...
# 30539                   YET ANOTHER HIGHLY OVERRATED FILM
# 464007                                Elementary Good Fun
# 301377  Jurassic Park III        10 out of 10    EXCEL...
# 242454       Disaster movie that packs a emotional wallop
# 546444          One of the best buddy-movies ever ! ! ! !
#
# [22000 rows x 7 columns]

# %%
# test dataset (6000 examples -- approxamately the same size as with neural network)
# balanced classes

small_spoiler_test = spoiler_reviews.sample(n=3000)
small_no_spoiler_test = no_spoiler_reviews.sample(n=3000)

val_reviews = pd.concat([small_spoiler_test, small_no_spoiler_test], ignore_index = False)
val_reviews
# Out:
#              review_date   movie_id     user_id  is_spoiler  \
# 371471        4 May 2006  tt0356680   ur9177788        True
# 331148  26 December 2004  tt0327056   ur1535417        True
# 501505     26 March 2012  tt0107614   ur6918917        True
# 64994    20 January 2007  tt0041959   ur4428199        True
# 48963     31 August 2013  tt0105236  ur46172017        True
# ...                  ...        ...         ...         ...
# 150209    21 August 2012  tt1229238  ur35537696       False
# 536199    22 August 2015  tt0118884   ur2898520       False
# 261419   10 January 2017  tt1860357  ur23018536       False
# 253595     30 March 2016  tt2948356  ur62417210       False
# 351398       4 July 2005  tt0361862   ur2973241       False
#
#                                               review_text  rating  \
# 371471  When will Hollywood get it? It is rare to for ...       4
# 331148  I must say I'm REALLY disappointed by this mov...       6
# 501505  Robin Williams, Sally Field and Pierce Brosnan...       7
# 64994   The Third Man is all sizzle and flimsy plot. T...       7
# 48963   This movie is my favourite movie of all time, ...      10
# ...                                                   ...     ...
# 150209  So I watched Mission Impossible: Ghost Protoco...       5
# 536199  Dr. Ellie Arroway (Jodie Foster) starts work f...       7
# 261419  "We are a big company, millions of moving part...       8
# 253595  Zootopia is the newest animated movie from Wal...      10
# 351398  Put succinctly, The Machinist isn't worth your...       4
#
#                                            review_summary
# 371471                                   Is it over yet?!
# 331148  Well directed, well acted but spoiled by a sil...
# 501505                             "One Of Robin's Best!"
# 64994                             All sizzle, flimsy plot
# 48963                                         Masterpiece
# ...                                                   ...
# 150209                   Fun, but in the end, forgettable
# 536199                                          Big ideas
# 261419  The action is quick and relentless and a movie...
# 253595                 Another modern classic from Disney
# 351398                  I've seen this creepy plot before
#
# [6000 rows x 7 columns]

# %%
# preprocessing (lowercase and nltk word tokenization)

def preprocess(text):
    text = text.lower()
    text = [token for token in word_tokenize(text) if token.isalpha()]
    text = ' '.join(text)

    return text

# %%
# tfidf

tfidf = TfidfVectorizer(stop_words='english', min_df=3)

train_texts = train_reviews.review_text.apply(preprocess).values

X_train = tfidf.fit_transform(train_texts).toarray()
y_train = train_reviews.is_spoiler.values

# %%
test_texts = val_reviews.review_text.apply(preprocess).values

X_test = tfidf.transform(test_texts).toarray()
y_test = val_reviews.is_spoiler.values

# %%
# learning

svm = LinearSVC()
svm.fit(X_train, y_train)
# Out:
# LinearSVC()

# %%
# accuracy

print(classification_report(y_test, svm.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.66      0.66      0.66      3000
#         True       0.66      0.66      0.66      3000
#
#     accuracy                           0.66      6000
#    macro avg       0.66      0.66      0.66      6000
# weighted avg       0.66      0.66      0.66      6000
